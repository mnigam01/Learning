# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### ticktacktoe
#
# ![image-2.png](attachment:image-2.png)

# %%
class Dog:
    def __init__(self,name, age):
        self._name = name
        self._age = age

    @property
    def name(self):
        return self._name   # give _ name here otherwise recursion error
    @name.setter
    def name(self,name):
        self._name = name
obj = Dog("moit", 22)
print(obj.name)
# Out:
# moit
